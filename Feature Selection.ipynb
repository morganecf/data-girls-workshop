# %%
'''Notebook to demonstrate basic feature extraction steps'''

# %%
import pandas as pd

df = pd.read_csv('sample_tweets.csv', encoding='latin-1')

# %%
# Remove mentions: might constitute noisy data
# since mentions are relatively unique
mention = r'^(.*\s)?@\w+'
df.text = df.text.str.replace(mention, '')

# %%
df.text.head()
# Out:
# 0     http://twitpic.com/2y1zl - Awww, that's a bum...
# 1    is upset that he can't update his Facebook by ...
# 2     I dived many times for the ball. Managed to s...
# 3      my whole body feels itchy and like its on fire
# 4     no, it's not behaving at all. i'm mad. why am...
# Name: text, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
CountVectorizer()
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
word_vectorizer = CountVectorizer(ngram_range=(1, 3))
s = 'We are really cool and awesome and boys suck'
word_vectorizer.fit_transform([s])
word_vectorizer.vocabulary_
# Out:
# {'and': 0,
#  'and awesome': 1,
#  'and awesome and': 2,
#  'and boys': 3,
#  'and boys suck': 4,
#  'are': 5,
#  'are really': 6,
#  'are really cool': 7,
#  'awesome': 8,
#  'awesome and': 9,
#  'awesome and boys': 10,
#  'boys': 11,
#  'boys suck': 12,
#  'cool': 13,
#  'cool and': 14,
#  'cool and awesome': 15,
#  'really': 16,
#  'really cool': 17,
#  'really cool and': 18,
#  'suck': 19,
#  'we': 20,
#  'we are': 21,
#  'we are really': 22}

# %%
from stop_words import get_stop_words
stop_words = get_stop_words('en')

# %%
stop_words.remove('not')

# %%
word_vectorizer = CountVectorizer(ngram_range=(1,3), stop_words=stop_words)

# %%
target = df.sentiment
tweets = df.text

# %%
word_doc_matrix = word_vectorizer.fit_transform(tweets)

# %%
word_doc_matrix
# Out:
# <9999x122701 sparse matrix of type '<class 'numpy.int64'>'
# 	with 194060 stored elements in Compressed Sparse Row format>

# %%
word_vectorizer.vocabulary_
# Out:
# {'thanks enjoying time': 103285,
#  'iphone 3bar gprs': 52549,
#  'gear wana': 38313,
#  'stack pointer': 97840,
#  'love pictures': 62828,
#  'sklov': 94551,
#  'thinking earlier': 104445,
#  'annoying weights 20': 5734,
#  'finish tomorrow yesssss': 34899,
#  'just pure junk': 54886,
#  'dragons': 28040,
#  'flex sample code': 35434,
#  'topshop bc': 107729,
#  'pospect 84': 81969,
#  'trash can': 108375,
#  'seriously good best': 92147,
#  'album september': 3996,
#  'lbs amp': 57900,
#  'spamming people tickets': 97183,
#  'regret not mercy': 87119,
#  'monster loca mocha': 68571,
#  'gee insomnia sucks': 38329,
#  'night throwing': 72952,
#  'bloggers now': 12469,
#  'morning tired lol': 69119,
#  '70000': 1888,
#  'tweetdeck http': 109642,
#  'encouraging': 30116,
#  'editing software timelines': 29471,
#  'wouldnt go far': 120271,
#  'breakfast banana': 13718,
#  'last half hour': 57259,
#  'night japan': 72827,
#  'redo sleeping patterns': 86971,
#  'lollypop': 61474,
#  'blogs don forget': 12483,
#  'wnt able': 118400,
#  'near future none': 70955,
#  'cool ig': 21431,
#  'suck many things': 100049,
#  'finished eating breakfast': 34927,
#  'genggong much': 38419,
#  'ordered new': 77775,
#  'ugly': 110811,
#  'work ahhh': 119100,
#  'ok ll just': 76278,
#  'dont wanna look': 27740,
#  'umm yeah': 110946,
#  'please god don': 81252,
#  'stayed longer lt': 98371,
#  'wicked mentioned': 117169,
#  'hole punch': 48339,
#  'contribute': 21250,
#  'kitty whole conferenceing': 56115,
#  'everyones laundry except': 31614,
#  'whoop de': 117116,
#  'maybe ever': 65808,
#  'breakdwon lol': 13707,
#  'another 350': 5768,
#  'suicides row': 100247,
#  'dbz': 24688,
#  'baby concert ll': 8700,
#  'sorta just found': 96891,
#  'passwords everyone': 79043,
#  'getting tooth': 39581,
#  'goes away': 40947,
#  'tigers amp': 105316,
#  'evening great': 31229,
#  'still trying finish': 98916,
#  'sway baby concert': 101135,
#  'peppers tonights': 79615,
#  'samro breaking': 89811,
#  'eeerrrrrrr': 29514,
#  'good night sleep': 42330,
#  'really hello peeps': 86402,
#  'bunny ranch': 14679,
#  'sounds fab bc': 97002,
#  'already done better': 4332,
#  'sisters': 94242,
#  'heart goes family': 47020,
#  'much never know': 69878,
#  'cake take home': 15249,
#  'antibiotics throat alcohol': 6007,
#  'going school': 41445,
#  'fucked sleep ive': 37422,
#  'speak boyfriend': 97239,
#  'africa skype miss': 3322,
#  'btw business card': 14363,
#  'nobody cakin': 73172,
#  'thinking day': 104443,
#  'foul right': 36419,
#  'consequences': 21081,
#  'lovely journal cover': 63119,
#  'machinecpa best day': 63991,
#  'sounds fair horrible': 97004,
#  'ride get harassed': 88122,
#  'fat': 33194,
#  'still dice': 98613,
#  'soon kinda sucks': 96412,
#  'sell cookies people': 91818,
#  'luck week miss': 63483,
#  'bronchitis': 14166,
#  'stay tune': 98352,
#  'eww snow': 31753,
#  'wish back': 117984,
#  'capture': 16609,
#  'dead house': 24730,
#  'well soon dear': 116523,
#  'just kidding great': 54666,
#  'gut': 44524,
#  'girlyvue back even': 39870,
#  'buy jb new': 15019,
#  'deceided scream hannah': 24904,
#  'past couple shows': 79065,
#  'iyar6d ep': 53113,
#  'everythings': 31701,
#  'blonde object mindvalley': 12507,
#  'fell half': 34019,
#  'interview cardiff today': 52427,
#  'rhythm gonna get': 88053,
#  'ugh wish redo': 110784,
#  'feat snoop dog': 33460,
#  'reset ipod reset': 87666,
#  'bball want phoebe': 10162,
#  '100 really useful': 200,
#  'cause not': 17149,
#  'dairy milk white': 23370,
#  '07 don know': 83,
#  'night year': 72999,
#  'budget yr': 14493,
#  'creaking': 22384,
#  'google hackathon thanks': 42634,
#  'covered poop picture': 22119,
#  'lanes': 57078,
#  'heard love': 46953,
#  'chairs': 17439,
#  'damn flash': 23453,
#  'pure dying': 83708,
#  'leno made': 58449,
#  'apo meetings': 6350,
#  'play kibum course': 81006,
#  'sleep early': 94690,
#  'ah enabler': 3581,
#  'maybe old buddy': 65849,
#  'now hear': 74762,
#  'show air tz': 93210,
#  'like aero': 59054,
#  'dragon': 28034,
#  'marc': 65266,
#  'ovr say': 78179,
#  'today afraid pushed': 106370,
#  'look cute sit': 61750,
#  'damn lorry van': 23482,
#  'manuscript tonight': 65121,
#  'greatness': 43938,
#  'wanna go fun': 114121,
#  'chat line': 17789,
#  'thanks everything lt': 103294,
#  'take damn': 101614,
#  'earlier lol': 28898,
#  'dear ty ll': 24845,
#  'shorts': 93097,
#  'whoever ayu ur': 117052,
#  'lerning really': 58466,
#  'phone waiting': 80038,
#  'much blessed much': 69726,
#  'delirious': 25215,
#  'neither huge fan': 71508,
#  'one isn hungry': 77003,
#  'now urrff': 75132,
#  'social club': 95630,
#  'bambootablet': 9751,
#  'know letting': 56424,
#  'permanent': 79711,
#  'just teeny bit': 55066,
#  'watching rocko': 115251,
#  'leave vegas sun': 58173,
#  'particually better one': 78887,
#  've sitting': 112678,
#  'well just': 116402,
#  'www stargazersrealm': 120790,
#  'want macbook': 114382,
#  'shame hear stephan': 92487,
#  'hahahahahhaa good one': 45262,
#  'beer pool': 10694,
#  'cause cousins': 17120,
#  'not everyone': 73660,
#  'seen months': 91739,
#  'beer toaster': 10700,
#  'don understand things': 27402,
#  'apparently': 6418,
#  'really didn mean': 86311,
#  'i36 hope': 50653,
#  'gutted couldnt get': 44538,
#  'yung': 122534,
#  'silly lady lol': 93849,
#  'http www zshare': 50184,
#  'will smith': 117641,
#  'want od': 114415,
#  'rowan atkiinson fantastic': 88934,
#  'tried never shows': 108580,
#  'good morning can': 42221,
#  'don sleep not': 27351,
#  '14 sleeps': 463,
#  'com single fixed': 20046,
#  've drawn': 112489,
#  'band ll still': 9803,
#  'mbma turf always': 65923,
#  'email one': 29934,
#  'now not freeview': 74909,
#  'feels sick': 33971,
#  '200 carrying': 798,
#  'disney channel jonas': 26464,
#  'manage take 75': 65000,
#  'peach gummi cheeto': 79293,
#  'hahahh': 45266,
#  'cake another': 15239,
#  '76 days till': 1916,
#  'fast lose eminem': 33162,
#  'begging turn': 10715,
#  'isnt': 52888,
#  'sleepy got': 94981,
#  'meningitis': 66534,
#  'deitrick': 25153,
#  'tegan': 102535,
#  'thinks fun': 104526,
#  'modeling change': 68237,
#  'tbh depressed': 102296,
#  'preferred gratuitous grossness': 82461,
#  'maybe ve': 65881,
#  'transforming owl': 108342,
#  'nbjwl': 70914,
#  'stop makes sad': 99107,
#  'argh fantasy surfer': 6859,
#  'see counting': 91200,
#  'woo fricken': 118901,
#  'pain lt gt': 78500,
#  'just content': 54347,
#  'ldn town heading': 57913,
#  'back college assignment': 8892,
#  'latest tracks nd': 57681,
#  'posts': 82159,
#  'not whole crew': 74320,
#  'aww poor froofroo': 8442,
#  'class http': 18717,
#  'still days another': 98609,
#  'trying extend reading': 108990,
#  'paramount pics': 78729,
#  'antony cooooome brazil': 6023,
#  'quot puts lotion': 84665,
#  'since ve': 94042,
#  'go chinatown': 40378,
#  'buy 1000000 minimum': 14977,
#  'wish afford galleries': 117980,
#  'coco': 19276,
#  'gee love': 38330,
#  'got big egoooo': 42834,
#  'babe fam annoys': 8648,
#  'left inner': 58305,
#  'really depressing': 86308,
#  'stale': 97892,
#  'book 99 shipping': 12872,
#  'get tickets show': 39197,
#  'buy expensive mac': 15008,
#  've got bag': 112540,
#  'jack': 53136,
#  'luke says': 63567,
#  'knackered': 56141,
#  'new transformer': 72146,
#  'got one reply': 43127,
#  'yesterday actually': 122019,
#  'girl dream': 39738,
#  'problema quot correct': 83031,
#  'well accessing': 116269,
#  'thanks letting': 103383,
#  'back bed feel': 8848,
#  'complain re': 20648,
#  'fresh missing': 36923,
#  'mereka tak faham': 66589,
#  'well much': 116452,
#  'agora sacooo': 3508,
#  'bad may': 9454,
#  'grouping': 44155,
#  'thats cold virus': 103599,
#  'isn truth': 52877,
#  'outside patio named': 78048,
#  'manda spending': 65064,
#  'quit smoking': 84090,
#  'wait launch': 113591,
#  'bad good luck': 9422,
#  'wow awhile': 120283,
#  'dollar fill': 27031,
#  'go outside get': 40616,
#  'done hopefully': 27518,
#  'exciting meeting twittering': 32089,
#  'txt updates': 110572,
#  'ace want': 2730,
#  'ok certificate': 76227,
#  'whitley lol': 117026,
#  'know use thing': 56627,
#  'hot humid': 49483,
#  'hill valley': 47992,
#  'even denial watch': 31046,
#  'vegas awww lt': 112734,
#  'ate mocha': 7565,
#  'closed time time': 19051,
#  'praying hang trust': 82401,
#  'hurts just bit': 50567,
#  'thingie dsn hv': 103952,
#  'can swim': 16188,
#  'cub gone work': 22782,
#  'link screams quot': 59929,
#  'call good': 15323,
#  'lotery stfu': 62391,
#  'design another relax': 25473,
#  'universe delivers': 111266,
#  'luke worral': 63569,
#  'personal pretty freaky': 79791,
#  'feeling cagey': 33818,
#  'well morning l0l': 116451,
#  'using mac': 112175,
#  'mouth less': 69347,
#  'good luckk': 42187,
#  'plane sucks': 80856,
#  'juggle tiki torches': 54066,
#  'become florists good': 10466,
#  'know andy hallet': 56247,
#  'didn tell tips': 25862,
#  'honest': 48781,
#  'line upset': 59868,
#  'permanent earache': 79714,
#  'apparently bus already': 6426,
#  'go college work': 40391,
#  'work couple': 119181,
#  'next week 24': 72390,
#  'hmmm well got': 48236,
#  'ff much appreciated': 34161,
#  'poxy': 82268,
#  'asleep right now': 7372,
#  'find amazing': 34594,
#  'politicians': 81676,
#  'packed like': 78325,
#  'whatta man': 116909,
#  'ummm fb likes': 110951,
#  'hoping somewhat productive': 49307,
#  'need better': 71043,
#  '16km bike': 592,
#  'first dm gets': 35089,
#  'dutch': 28748,
#  'will baking butt': 117289,
#  'bed suddenly feel': 10611,
#  'beats sleep': 10354,
#  'try one like': 108929,
#  'dream shoes': 28147,
#  'got odbc': 43113,
#  'england though gorgeous': 30265,
#  'lt eliza dushku': 63299,
#  'reminds germany': 87368,
#  'com greek': 19951,
#  'gaining': 37953,
#  'pupe ameba': 83672,
#  'head ache': 46547,
#  'filipino programming': 34321,
#  'shitty fucking fillings': 92863,
#  'mine gonna': 67317,
#  'today regreting decisioin': 106787,
#  'gotten porn spammers': 43450,
#  'last year': 57435,
#  'damn hackers amp': 23470,
#  'twurl': 110542,
#  'one wichita': 77248,
#  'pooh': 81716,
#  'maybe aa': 65769,
#  'grant': 43592,
#  'anywhere oh': 6315,
#  'errands not italia': 30760,
#  'lesson maths': 58515,
#  'obama fashion icon': 75446,
#  'always sucks': 4727,
#  'pollen trees washington': 81690,
#  'harsher http': 46031,
#  'quite snow frozen': 84136,
#  'waiting perrrfect moment': 113789,
#  'managed cross legs': 65006,
#  'records mp4': 86880,
#  'noted majority people': 74377,
#  'watching himym seas': 115178,
#  'back soon': 9188,
#  'now sad cos': 74995,
#  'light keg': 59002,
#  'song cassie lt': 96217,
#  'fridays really appreciate': 37001,
#  'may wait': 65756,
#  'intr search follow': 52472,
#  '5am go online': 1734,
#  'cant invite': 16478,
#  'ah gotcha still': 3588,
#  'll miss today': 60722,
#  'thinking pay day': 104495,
#  'afternoon guessing re': 3352,
#  'mizdayenet feel better': 68114,
#  'negative': 71464,
#  'feel bad get': 33573,
#  'tiny shoes app': 106021,
#  'hahahahhha hows food': 45265,
#  'client ve ever': 18948,
#  'george': 38442,
#  'broadcasting show thurs': 14092,
#  'phone calls': 79953,
#  'lol episodes season': 61201,
#  'visit shouldn': 113221,
#  'star trek': 97964,
#  'nap interrupted': 70767,
#  'friends end 1st': 37141,
#  'turtles yet': 109416,
#  'gotta get learning': 43373,
#  'quot jeremy': 84461,
#  'cold might help': 19489,
#  'dmb cd': 26641,
#  'box throw': 13406,
#  'find awk sed': 34606,
#  'can google': 15881,
#  'hell journey': 47247,
#  'chef chopra': 18064,
#  'feeling even worse': 33826,
#  'position ve just': 81959,
#  'sing loud': 94071,
#  'day sun': 24400,
#  'neva knw': 71616,
#  'hour 33gb 60': 49577,
#  'jay leno': 53303,
#  'sending email': 91952,
#  '7j66t': 1980,
#  'got back stage': 42817,
#  'canadian service wouldn': 16346,
#  'stone end year': 99047,
#  'got yoghurt': 43336,
#  'blazer': 12209,
#  'back disconnected break': 8916,
#  'hadn seen': 44893,
#  'done uni': 27583,
#  'notifications phone except': 74512,
#  'really necessary': 86472,
#  'nahi kiya baad': 70623,
#  'free': 36703,
#  'usually express asked': 112240,
#  'want scream': 114456,
#  'grandma shes': 43580,
#  'soo horrible': 96338,
#  'yeahh eat': 121555,
#  'darlings eyebrow': 23735,
#  'together last night': 107002,
#  '12 gym class': 364,
#  'day swelling': 24404,
#  'shoes lucky not': 92938,
#  'finally long day': 34517,
#  'mediafire': 66216,
#  'supported stood behind': 100735,
#  'closed cause': 19038,
#  'seems like laws': 91679,
#  'goes many ff': 40966,
#  'time add': 105462,
#  'sleep lately stressed': 94761,
#  'time ba': 105474,
#  'telecom works wifi': 102557,
#  'congratulations re 70th': 21028,
#  'worried dont': 120086,
#  'decent exchange rate': 24917,
#  'freedeom': 36812,
#  'already booked': 4325,
#  'stuff come new': 99752,
#  'sweat pants look': 101162,
#  'comming something': 20505,
#  '__ ahaha': 2341,
#  'sa lahat http': 89290,
#  'working well': 119838,
#  'come onto pitch': 20197,
#  'vacay': 112335,
#  'boring ugh': 13180,
#  'visitors unfortunately': 113249,
#  'sigh gonna': 93727,
#  'heaps not happy': 46777,
#  'buy birthday cake': 14989,
#  'kind wishes': 55970,
#  'll go look': 60658,
#  'enjoy love homestead': 30337,
#  'effing points': 29546,
#  'know hate': 56384,
#  'seeing old buddy': 91576,
#  'train everybody try': 108236,
#  'tomorrow work': 107321,
#  'got margarita pizza': 43074,
#  'dude may': 28577,
#  '24 boring madame': 907,
#  'dublin time college': 28550,
#  'love moo keep': 62773,
#  'ohh hope': 76148,
#  'working paperwork': 119790,
#  'seems long': 91686,
#  'highly recommended ever': 47928,
#  'whoo': 117105,
#  'love past 7yrs': 62815,
#  'gawk reminds legally': 38212,
#  'close current': 18996,
#  'fugly poker': 37477,
#  'kingsbridge': 56043,
#  'oceans contain': 75538,
#  'return serious': 87863,
#  'alike': 4079,
#  'mode today kids': 68228,
#  'mayyyyy lost ring': 65911,
#  'ft': 37346,
#  'tescos': 102846,
#  'ready keynote semtech2009': 86038,
#  'get 41 words': 38509,
#  'tomorrow damn': 107177,
#  'coming soon feeling': 20429,
#  'working laptop go': 119756,
#  'stuffy nose': 99849,
#  'go guys tmrw': 40491,
#  'didnt come today': 25903,
#  'amp laundry today': 5211,
#  'game amazing': 37989,
#  'later not': 57627,
#  '69': 1826,
#  'upclose personal': 111387,
#  'much mind': 69859,
#  'sind echt': 94058,
#  'brought back many': 14257,
#  'like rain today': 59449,
#  'cabs': 15195,
#  'vhs cried old': 112879,
#  'follow wish': 35823,
#  'wi father': 117156,
#  'forward morning waves': 36367,
#  'im yellinq': 51488,
#  'amp reviewed correctly': 5312,
#  'york new york': 122362,
#  'dont wanna move': 27742,
#  'ferdinand mas': 34103,
#  'en esa pagina': 30106,
#  'buying lazrtag': 15086,
#  'll not': 60749,
#  'inspirational saddening time': 52118,
#  'using wrong code': 112205,
#  'damn hang': 23471,
#  'get caught mail': 38628,
#  'really sleepy mad': 86563,
#  'rooibos': 88714,
#  'baby stuff pleaaase': 8767,
#  'moon spoke': 68700,
#  'love pictures re': 62830,
#  'thiinkiin bout': 103802,
#  'gonna ask plan': 41735,
#  'washingtondc': 114786,
#  'give wave sunday': 39978,
#  'protesting quot getting': 83412,
#  'sure get see': 100858,
#  'thurs nite hubs': 105136,
#  'justgiving related': 55260,
#  'sucks hard': 100104,
#  'skip school': 94525,
#  'day manu season': 24223,
#  'celebration': 17292,
#  'sitting warm bed': 94422,
#  'home now sad': 48591,
#  'test papers ready': 102882,
#  'car park always': 16658,
#  'night gal man': 72789,
#  'autograph': 7848,
#  'suites': 100270,
#  'tracy girl piece': 108166,
#  'direct message got': 26248,
#  'waiting update': 113814,
#  'love guys': 62665,
#  'switched long': 101339,
#  'looking shoes': 61998,
#  'bad just': 9439,
#  'arlene makeup': 6918,
#  'sessions done xbox': 92249,
#  '29 not one': 983,
#  'sometime xxxxx': 96100,
#  'able afford get': 2466,
#  'road hope not': 88470,
#  'bed hour': 10558,
#  'yeap ash': 121569,
#  'past': 79044,
#  'ppl decide': 82282,
#  'never old': 71718,
#  '2y4vn remember days': 1133,
#  'find matzah': 34668,
#  'project school hard': 83264,
#  'make shit': 64535,
#  'fraser': 36660,
#  'travian total': 108412,
#  'love band': 62529,
#  'team please': 102399,
#  'one 25th': 76761,
#  'falling stairs not': 32815,
#  'gym amp': 44713,
#  'morning hospital': 68951,
#  'publishing don': 83568,
#  'technically looked': 102452,
#  'soon great': 96392,
#  'knocked bike': 56227,
#  'crap water': 22277,
#  'begin': 10717,
#  'used avatar whats': 112037,
#  'head hurts thinking': 46581,
#  'think people choose': 104316,
#  'tadi': 101533,
#  'course thank inventing': 22046,
#  'good movie good': 42299,
#  'watch tv': 115017,
#  'sleepy tweepy lol': 95008,
#  'shld ashamed smh': 92877,
#  'leave twitter': 58169,
#  'idiot just': 50835,
#  'home shitty': 48614,
#  'need golden shoe': 71168,
#  'deadline close easter': 24765,
#  'raining oh wait': 85125,
#  'll still way': 60835,
#  'changed hopes means': 17571,
#  'just fell flat': 54436,
#  'powerful beautiful definately': 82251,
#  'curse ye': 22941,
#  'aww think becky': 8468,
#  'morning everyone surprisingly': 68867,
#  'new album quot': 71806,
#  'goodly': 42551,
#  'clearer': 18864,
#  'php hosting provider': 80158,
#  'socal shop wait': 95623,
#  'study exams': 99695,
#  'swapping': 101118,
#  'company hope enjoyed': 20591,
#  'day feel': 24046,
#  'days im way': 24572,
#  'removed bookmarks folder': 87392,
#  'thats ok ll': 103639,
#  'green luas': 43987,
#  'allows go': 4173,
#  'twitter client commodore': 110099,
#  'next flight': 72329,
#  'wings won': 117906,
#  'best luck': 11040,
#  'tmoz sometime': 106307,
#  'moo ice cream': 68658,
#  'sick today hoping': 93648,
#  'therefore main': 103738,
#  'email address dude': 29917,
#  'cross county': 22597,
#  'mad ima mothafuckin': 64017,
#  'last grad': 57252,
#  'cool bad': 21388,
#  'assembley': 7433,
#  'take key': 101650,
#  '4ward': 1635,
#  'hello slow': 47332,
#  'blue things distract': 12630,
#  'grumpy though makes': 44226,
#  'see thats never': 91460,
#  'steph maria now': 98442,
#  'us know think': 111844,
#  'much hotter': 69804,
#  'tonight swear can': 107494,
#  'fuck rude': 37404,
#  'timeliness swedish rail': 105914,
#  'grab heroes': 43499,
#  'yes great mind': 121860,
#  'despite despair': 25530,
#  'size 00': 94454,
#  'machines': 63992,
#  'thing moscow behind': 103876,
#  'stay away frm': 98319,
#  'shows pbs': 93430,
#  'buy ambients': 14984,
#  'early stay': 29011,
#  'will sad': 117609,
#  'picking dress': 80320,
#  'nice person though': 72571,
#  'sok ve got': 95749,
#  'someone get work': 95874,
#  'svc iphone': 101088,
#  '12 hours assessments': 370,
#  'sleep now johnny': 94815,
#  'soo wish': 96352,
#  'anyone maybe just': 6145,
#  'gal noe best': 37962,
#  'gear returns': 38309,
#  'super adventurous days': 100629,
#  'butterfly jason mraz': 14949,
#  'dresserupper': 28226,
#  'still work': 98957,
#  'cables': 15188,
#  'dane marlon amp': 23637,
#  'everyone try': 31588,
#  'mailing info via': 64310,
#  'thank tasty': 103161,
#  'start finalize': 98057,
#  'everyone hope take': 31529,
#  '64 go': 1805,
#  'braces': 13518,
#  '2am not bit': 997,
#  'major': 64363,
#  'see tweet': 91475,
#  'beware last': 11383,
#  'midnight walk still': 66914,
#  'cool stuff http': 21488,
#  'shopto': 93051,
#  'cycle2work scheme 15': 23217,
#  'classes': 18751,
#  're tweet': 85741,
#  'males': 64817,
#  'hot hard': 49478,
#  'fire amp pumping': 35015,
#  'poets': 81560,
#  'like apologize': 59068,
#  'sam sick': 89795,
#  'forgot sleep': 36226,
#  'sorry got': 96727,
#  'clarkson': 18689,
#  'rice delivery well': 88064,
#  'unknown reason': 111286,
#  'looks like angel': 62037,
#  'sligo': 95095,
#  'lol nope': 61336,
#  'sleep frustrating': 94708,
#  'new tv': 72148,
#  'feels wearing tie': 33976,
#  'musik quot like': 70272,
#  'hope gain speech': 49002,
#  'real quot': 86131,
#  'cheap holiday': 17829,
#  'sadly not feed': 89562,
#  'short easter holidays': 93060,
#  'woke really early': 118500,
#  'fundraising not': 37725,
#  'follow ethanchoo': 35777,
#  'lovely': 63085,
#  'fellow commuters vile': 34043,
#  'tomorrow coraline night': 107176,
#  'like neglected': 59381,
#  'birthday momma going': 11783,
#  'know still brought': 56587,
#  'quiz online': 84158,
#  'ooh get': 77424,
#  'forums nightmare': 36313,
#  'journey way': 53992,
#  'please tell': 81311,
#  'today 30': 106360,
#  'call female': 15321,
#  'boring suckassy': 13174,
#  'never get reply': 71674,
#  'sad sad': 89479,
#  'amp ignorance': 5176,
#  'todayyyy': 106974,
#  'boring worse guess': 13189,
#  'pixar making monsters': 80711,
#  'impulsive not stupid': 51700,
#  'kh gi ng': 55671,
#  'somethin fallen car': 95968,
#  'lvatt said 930': 63736,
#  'teeth love': 102523,
#  'feature 416950': 33462,
#  'reheated pizza': 87158,
#  'situation write': 94438,
#  'singer mentioned long': 94098,
#  'neglected twilight': 71469,
#  'suppose': 100742,
#  'week hope can': 115957,
#  'expensive amp pretty': 32199,
#  'jade looking': 53165,
#  'see photos': 91392,
#  'mac lasts longer': 63925,
#  'better watch': 11359,
#  'please share like': 81298,
#  'ticket month old': 105220,
#  'announcement whenever': 5689,
#  'soup drinken': 97047,
#  'make show': 64536,
#  'healthy teeth': 46770,
#  'great giveaway': 43726,
#  'favorite teams astros': 33351,
#  'haha know eh': 45006,
#  'si habla': 93494,
#  'baldwin': 9695,
#  'hope old border': 49100,
#  'snap ll just': 95459,
#  'just put yesterday': 54892,
#  'nawal fe obeerate': 70896,
#  'like working': 59675,
#  'jealous going london': 53367,
#  'priced good': 82797,
#  'search follow official': 90942,
#  'windows browse twitter': 117857,
#  'regret get': 87116,
#  'gotta throw bigrun': 43424,
#  'rocked one': 88578,
#  'positive reason': 81966,
#  'pls photos not': 81396,
#  'cut break heart': 23027,
#  'just girl thing': 54519,
#  'closed mondays sad': 19046,
#  'link www': 59948,
#  'say soundchek': 90226,
#  'yummy': 122520,
#  'home need car': 48583,
#  'us know ok': 111841,
#  'gosh looks like': 42732,
#  'couple hours': 21958,
#  'go run around': 40654,
#  'twitters quase de': 110414,
#  'shot http': 93115,
#  'time': 105458,
#  'grinding boiling': 44071,
#  'pah': 78440,
#  'general': 38392,
#  'search bar come': 90931,
#  'working rite': 119799,
#  'bashed': 10011,
#  'well hate alabaster': 116375,
#  'received answer ticket': 86773,
#  'cough seem': 21758,
#  'listening quot': 60168,
#  'surplus carlinll blogspot': 101005,
#  'next expenditure french': 72326,
#  'although without tunes': 4579,
#  'exam go': 31816,
#  'cloudy virgin': 19115,
#  'amazing': 4794,
#  'yeah home': 121422,
#  'groat': 44083,
#  'praise band': 82351,
#  'wondering tips writers': 118838,
#  'darling still friday': 23732,
#  'now using stupid': 75136,
#  'just trying help': 55113,
#  'things waiting': 104065,
#  'chronic ones': 18498,
#  'gonna try get': 41883,
#  'stain dentist': 97876,
#  'zb': 122593,
#  'rocketdock awesome': 88585,
#  'requires assembly': 87616,
#  'lauren rutherford': 57785,
#  'aw suuuucks sorry': 7957,
#  'starbucks heidi don': 97990,
#  'mst even': 69642,
#  'late not': 57527,
#  'sugarland live': 100224,
#  'hoping well exam': 49317,
#  'paintingg amp': 78556,
#  'goshh': 42751,
#  'ice cream hear': 50692,
#  'wear medium small': 115645,
#  'ashley simpson going': 7243,
#  'can tiring': 16213,
#  'half hours': 45369,
#  'much seattle like': 69921,
#  'like amazing': 59062,
#  'welcome glad': 116233,
#  'following iranian revolution': 35929,
#  'thing myspace': 103879,
#  'bt': 14342,
#  'hope includes': 49045,
#  'll hospital tomorrow': 60674,
#  '49': 1589,
#  'kind rock': 55952,
#  'dear omg': 24833,
#  'disappointing science golden': 26326,
#  'sing wish': 94079,
#  'omgawd couldnt handle': 76726,
#  'main reason': 64326,
#  'not good munchkinster': 73792,
#  'not far planned': 73681,
#  'downstairs kinda': 27958,
#  'name coz': 70668,
#  'gives shit lol': 40013,
#  'torrents taking': 107769,
#  'bit ly rixnb': 11946,
#  'plus saved 30': 81486,
#  'weekend go': 116060,
#  'lost cause girl': 62223,
#  'obnoxiously': 75468,
#  'nothing eat': 74421,
#  'body mine gonna': 12742,
#  'not freeview not': 73720,
#  'hell maybe not': 47254,
#  'us jump hour': 111838,
#  'chat even': 17776,
#  'apa neh': 6334,
#  'living': 60494,
#  'billion tons': 11631,
#  'commuting packed': 20565,
#  'mix well together': 68105,
#  'going today will': 41549,
#  'prayers go people': 82391,
#  'dark chocolate rocks': 23696,
#  'metal http bit': 66706,
#  'atlanta': 7609,
#  'hate gold syf': 46137,
#  'days now': 24602,
#  'observation fetching': 75474,
#  'ugly amazing': 110812,
#  'work university construction': 119581,
#  'late nights': 57525,
#  'view pages tweets': 113079,
#  'kids shows pbs': 55821,
#  'later semi': 57638,
#  'http digg com': 50031,
#  'tdmstr': 102310,
#  'fuckin': 37436,
#  'usual bad acting': 112214,
#  'well understand ll': 116578,
#  'guys fine': 44631,
#  'miss like crazy': 67699,
#  'portugal': 81942,
#  'new running': 72077,
#  'time buy sony': 105499,
#  'dentist time': 25328,
#  'kinko oh gonna': 56048,
#  'park hate': 78789,
#  'com 7fbc6 funny': 19748,
#  'hurt exercising': 50507,
#  'yesterday fingers': 122051,
#  'looking seem getting': 61994,
#  'never shows': 71743,
#  'always happens': 4649,
#  'edit friday will': 29454,
#  'behind video games': 10781,
#  'seen ds9 ve': 91721,
#  'margarhitas telll': 65286,
#  'likely ll get': 59716,
#  'done now need': 27548,
#  'hates maths tuition': 46269,
#  'work keeping average': 119345,
#  'wolfram alpha http': 118543,
#  'day quot truth': 24322,
#  'foggy skies sucks': 35715,
#  'hillsong said couldn': 48036,
#  'petition closes nov': 79847,
#  'quot yup': 84908,
#  'haha sorreh': 45099,
#  'heard concert marburg': 46926,
#  'slides': 95069,
#  'outshines ccx': 78002,
#  'discover': 26372,
#  'reply directly re': 87515,
#  'com 2y7bg ashley': 19708,
#  'dongle': 27609,
#  'finally get see': 34482,
#  'awww surely': 8526,
#  '4123a see varier': 1520,
#  'us mike understand': 111863,
#  'old world misses': 76565,
#  'feeling wanna': 33919,
#  've begun three': 112461,
#  'tomorrow called': 107162,
#  'now tho': 75093,
#  'ipod 1000th follower': 52622,
#  'getting work done': 39602,
#  'embarrased': 29974,
#  'find patch': 34684,
#  'forgotten table drinks': 36244,
#  'hope artwork': 48884,
#  'mmuk09 moodle must': 68168,
#  'just saw website': 54960,
#  'past experiences': 79070,
#  'reach axis': 85775,
#  'frm wil jst': 37261,
#  'flashing knickers': 35375,
#  'easily today': 29140,
#  'get see today': 39110,
#  'just miscarriage amp': 54790,
#  'please work 45': 81327,
#  'bali now': 9701,
#  'rolls http tinyurl': 88677,
#  'massage yep meme': 65476,
#  'crawl duvet': 22335,
#  'probably still worth': 82968,
#  'adviser': 3231,
#  'hedgefund': 47102,
#  'windy april': 117885,
#  'absolutely right best': 2560,
#  'baby boo': 8686,
#  'nooooo': 73335,
#  'hate software update': 46200,
#  'germany illegal sort': 38479,
#  'll need find': 60733,
#  'weekend food': 116057,
#  'not calorie': 73567,
#  'friends lol met': 37172,
#  'zipping back': 122632,
#  'get hanging': 38805,
#  'sleep body': 94645,
#  'damn dental': 23441,
#  'today doesn': 106487,
#  'part show': 78871,
#  ...}

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer(use_idf=True)
word_doc_tfidf_matrix = tfidf_transformer.fit_transform(word_doc_matrix)

# %%
word_doc_tfidf_matrix
# Out:
# <9999x122701 sparse matrix of type '<class 'numpy.float64'>'
# 	with 194060 stored elements in Compressed Sparse Row format>

# %%
from sklearn.naive_bayes import GaussianNB

subset = df.sample(n=1000, random_state=1234)

word_vectorizer = CountVectorizer(ngram_range=(1,3), stop_words=stop_words)
tfidf_transformer = TfidfTransformer(use_idf=True)

word_doc_matrix = word_vectorizer.fit_transform(subset.text)
features = tfidf_transformer.fit_transform(word_doc_matrix)

model = GaussianNB()

# Train the model 
classifier = model.fit(features.toarray(), subset.sentiment)

# %%
def predict_sentiment(new_tweets):
    counts = word_vectorizer.transform(new_tweets)
    tfidfs = tfidf_transformer.transform(counts)
    predictions = classifier.predict(tfidfs.toarray())
    return predictions

# %%
predict_sentiment(['i hate life'])
# Out:
# array([0])

# %%
predict_sentiment(['i am happy!!!'])
# Out:
# array([4])

# %%
predict_sentiment(['i like cats', 'i like tea', 'the weather is terrible', 'i do not want to go to work', 'life is wonderful'])
# Out:
# array([4, 4, 0, 0, 4])
